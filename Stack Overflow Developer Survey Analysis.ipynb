# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/dell/Desktop/pandas demo/data/survey_results_public.csv',index_col='Respondent')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
schema_df=pd.read_csv('C:/Users/dell/Desktop/pandas demo/data/survey_results_schema.csv',index_col='Column')

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
df['Country'].tail(10)
# Out:
# Respondent
# 88062              NaN
# 88076              NaN
# 88182         Pakistan
# 88212            Spain
# 88282    United States
# 88377           Canada
# 88601              NaN
# 88802              NaN
# 88816              NaN
# 88863            Spain
# Name: Country, dtype: object

# %%
df.Country
# Out:
# Respondent
# 1                United Kingdom
# 2        Bosnia and Herzegovina
# 3                      Thailand
# 4                 United States
# 5                       Ukraine
#                   ...
# 88377                    Canada
# 88601                       NaN
# 88802                       NaN
# 88816                       NaN
# 88863                     Spain
# Name: Country, Length: 88883, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df[['Country','Student']]
# Out:
#                            Country         Student
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time
# 3                         Thailand              No
# 4                    United States              No
# 5                          Ukraine              No
# ...                            ...             ...
# 88377                       Canada              No
# 88601                          NaN             NaN
# 88802                          NaN             NaN
# 88816                          NaN             NaN
# 88863                        Spain  Yes, full-time
#
# [88883 rows x 2 columns]

# %%
df.iloc[0:3]
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
# 3                             Never
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# ...

# %%
df.iloc[[0,3],2]
# Out:
# Respondent
# 1    Never
# 4    Never
# Name: OpenSourcer, dtype: object

# %%
df.loc[1].tail(4)
# Out:
# Ethnicity                              NaN
# Dependents                              No
# SurveyLength         Appropriate in length
# SurveyEase      Neither easy nor difficult
# Name: 1, dtype: object

# %%
df.loc[1].head(5)
# Out:
# MainBranch                I am a student who is learning to code
# Hobbyist                                                     Yes
# OpenSourcer                                                Never
# OpenSource     The quality of OSS and closed source software ...
# Employment                Not employed, and not looking for work
# Name: 1, dtype: object

# %%
df.loc[[1,2]]
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 1           I am a student who is learning to code      Yes
# 2           I am a student who is learning to code       No
#
#                         OpenSourcer  \
# Respondent
# 1                             Never
# 2           Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# ...

# %%
df.loc[[1,2],['Country','Student']]
# Out:
#                            Country         Student
# Respondent
# 1                   United Kingdom              No
# 2           Bosnia and Herzegovina  Yes, full-time

# %%
df.loc[[1,85],['Country','Student']]
# Out:
#                    Country Student
# Respondent
# 1           United Kingdom      No
# 85                 Germany      No

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[1].head(5)
# Out:
# MainBranch                I am a student who is learning to code
# Hobbyist                                                     Yes
# OpenSourcer                                                Never
# OpenSource     The quality of OSS and closed source software ...
# Employment                Not employed, and not looking for work
# Name: 1, dtype: object

# %%
df.loc[1,'Hobbyist']
# Out:
# 'Yes'

# %%
df.loc[1:3,'Hobbyist':'OpenSource']
# Out:
#            Hobbyist              OpenSourcer  \
# Respondent
# 1               Yes                    Never
# 2                No  Less than once per year
# 3               Yes                    Never
#
#                                                    OpenSource
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...

# %%
df.loc[1].head(3)
# Out:
# MainBranch     I am a student who is learning to code
# Hobbyist                                          Yes
# OpenSourcer                                     Never
# Name: 1, dtype: object

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['MgrIdiot':'MgrWant']
# Out:
#                                                QuestionText
# Column
# MgrIdiot  How confident are you that your manager knows ...
# MgrMoney  Do you believe that you need to be a manager t...
# MgrWant   Do you want to become a manager yourself in th...

# %%
schema_df.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Age                     What is your age (in years)? If you prefer not...
# Age1stCode              At what age did you write your first line of c...
# BetterLife              Do you think people born today will have a bet...
# BlockchainIs            Blockchain / cryptocurrency technology is prim...
# BlockchainOrg           How is your organization thinking about or imp...
# CareerSat               Overall, how satisfied are you with your caree...
# CodeRev                          Do you review code as part of your work?
# CodeRevHrs              On average, how many hours per week do you spe...
# CompFreq                 Is that compensation weekly, monthly, or yearly?
# CompTotal               What is your current total compensation (salar...
# Containers              How do you use containers (Docker, Open Contai...
# ConvertedComp           Salary converted to annual USD salaries using ...
# ...

# %%
countries=['United States','India','Canada']
high_salary= (df['ConvertedComp']>70000) & (df['Country'].isin(countries))&(df['LanguageWorkedWith'].str.contains('Scala',na=False))

# %%
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                   Country                                 LanguageWorkedWith  \
# Respondent
# 206         United States                                          Scala;SQL
# 273                Canada  Bash/Shell/PowerShell;C++;Clojure;Erlang;HTML/...
# 390         United States  Bash/Shell/PowerShell;HTML/CSS;Java;Kotlin;Pyt...
# 915                Canada  Bash/Shell/PowerShell;C#;F#;Java;Kotlin;Scala;...
# 972         United States                  Bash/Shell/PowerShell;C;Scala;SQL
# ...                   ...                                                ...
# 88758       United States        Bash/Shell/PowerShell;Java;Python;Scala;SQL
# 88874       United States                               C++;Python;Scala;SQL
# 88876       United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88877       United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88878       United States               HTML/CSS;JavaScript;Scala;TypeScript
#
#             ConvertedComp
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df.columns=df.columns.str.replace('ConvertedComp','SalaryUSD',)

# %%
df.head(5)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.sort_values(by='SalaryUSD',ascending=True)
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 85076       I am a developer by profession       No
# 52076       I am a developer by profession      Yes
# 29186       I am a developer by profession      Yes
# 65688       I am a developer by profession      Yes
# 1501        I am a developer by profession      Yes
# ...                                    ...      ...
# 88377                                  NaN      Yes
# 88601                                  NaN       No
# 88802                                  NaN       No
# 88816                                  NaN       No
# 88863                                  NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 85076                                 Less than once per year
# 52076       Less than once a month but more than once per ...
# 29186                              Once a month or more often
# ...

# %%
df.sort_values(by=['SalaryUSD','Country'],ascending=[True,False]).head(5)
# Out:
#                                 MainBranch Hobbyist              OpenSourcer  \
# Respondent
# 75010       I am a developer by profession       No                    Never
# 82369       I am a developer by profession       No                    Never
# 280         I am a developer by profession      Yes  Less than once per year
# 4073        I am a developer by profession      Yes  Less than once per year
# 4770        I am a developer by profession      Yes  Less than once per year
#
#                                                    OpenSource  \
# Respondent
# 75010       The quality of OSS and closed source software ...
# 82369       OSS is, on average, of LOWER quality than prop...
# 280         OSS is, on average, of HIGHER quality than pro...
# 4073        The quality of OSS and closed source software ...
# 4770        OSS is, on average, of HIGHER quality than pro...
#
#                                                    Employment  \
# Respondent
# ...

# %%
df[['SalaryUSD','Country']].head(10)
# Out:
#             SalaryUSD                               Country
# Respondent
# 75010             0.0  Venezuela, Bolivarian Republic of...
# 82369             0.0                            Uzbekistan
# 280               0.0                         United States
# 4073              0.0                         United States
# 4770              0.0                         United States
# 7254              0.0                         United States
# 11961             0.0                         United States
# 13975             0.0                         United States
# 16363             0.0                         United States
# 17015             0.0                         United States

# %%
df.median()
# Out:
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs           Age
# count  5.594500e+04  5.582300e+04  64503.000000  49790.000000  79210.000000
# mean   5.519014e+11  1.271107e+05     42.127197      5.084308     30.336699
# std    7.331926e+13  2.841523e+05     37.287610      5.513931      9.178390
# min    0.000000e+00  0.000000e+00      1.000000      0.000000      1.000000
# 25%    2.000000e+04  2.577750e+04     40.000000      2.000000     24.000000
# 50%    6.200000e+04  5.728700e+04     40.000000      4.000000     29.000000
# 75%    1.200000e+05  1.000000e+05     44.750000      6.000000     35.000000
# max    1.000000e+16  2.000000e+06   4850.000000     99.000000     99.000000

# %%
df['SocialMedia'].value_counts(ascending=True)
# Out:
# Hello                          19
# Youku Tudou 优酷                 21
# Weibo 新浪微博                     56
# VK ВКонта́кте                 603
# Snapchat                      628
# WeChat 微信                     667
# LinkedIn                     4501
# I don't use social media     5554
# Instagram                    6261
# Twitter                     11398
# Facebook                    13178
# WhatsApp                    13347
# YouTube                     13830
# Reddit                      14374
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize=True,ascending=True)
# Out:
# Hello                       0.000225
# Youku Tudou 优酷              0.000249
# Weibo 新浪微博                  0.000663
# VK ВКонта́кте               0.007141
# Snapchat                    0.007437
# WeChat 微信                   0.007899
# LinkedIn                    0.053306
# I don't use social media    0.065777
# Instagram                   0.074150
# Twitter                     0.134988
# Facebook                    0.156069
# WhatsApp                    0.158071
# YouTube                     0.163791
# Reddit                      0.170233
# Name: SocialMedia, dtype: float64

# %%
country_group= df.groupby(['Country'])

# %%
country_group['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
country_group['SocialMedia'].value_counts(normalize=True).loc[['India','China']]
# Out:
# Country  SocialMedia
# China    WeChat 微信                   0.670549
#          YouTube                     0.088186
#          Weibo 新浪微博                  0.069884
#          I don't use social media    0.044925
#          Twitter                     0.044925
#          Reddit                      0.019967
#          LinkedIn                    0.018303
#          Facebook                    0.013311
#          Instagram                   0.011647
#          Youku Tudou 优酷              0.011647
#          WhatsApp                    0.004992
#          VK ВКонта́кте               0.001664
# India    WhatsApp                    0.342379
#          YouTube                     0.208405
#          LinkedIn                    0.109355
#          Facebook                    0.096301
#          Instagram                   0.094126
#          Twitter                     0.062063
#          Reddit                      0.054162
#          I don't use social media    0.028627
# ...

# %%
country_group['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: SalaryUSD, Length: 179, dtype: float64

# %%
country_group['SalaryUSD'].median().loc[['India','Germany']]
# Out:
# Country
# India      10080.0
# Germany    63016.0
# Name: SalaryUSD, dtype: float64

# %%
country_group['SalaryUSD'].agg(['median','mean']).loc[['India','Germany']]
# Out:
#           median           mean
# Country
# India    10080.0   28057.664916
# Germany  63016.0  109256.884066

# %%
country_group['LanguageWorkedWith'].value_counts(['Python'])
# Out:
# Country      LanguageWorkedWith
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL                0.076923
#              HTML/CSS;Java;JavaScript;PHP;Python;SQL    0.051282
#              HTML/CSS;Java;PHP;SQL                      0.051282
#              Python                                     0.051282
#              Assembly                                   0.025641
#                                                           ...
# Zimbabwe     HTML/CSS;Python;SQL                        0.025641
#              Java;JavaScript;Kotlin;Python              0.025641
#              Java;JavaScript;SQL                        0.025641
#              Objective-C                                0.025641
#              Python                                     0.025641
# Name: LanguageWorkedWith, Length: 48114, dtype: float64

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python'))
# Out:
# Respondent
# 75010    False
# 82369     True
# 280      False
# 4073     False
# 4770      True
#          ...
# 88062      NaN
# 88076      NaN
# 88601      NaN
# 88802      NaN
# 88816      NaN
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
country_respondents=df['Country'].value_counts()

# %%
country_respondents
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Sao Tome and Principe                   1
# Saint Vincent and the Grenadines        1
# North Korea                             1
# Brunei Darussalam                       1
# Dominica                                1
# Name: Country, Length: 179, dtype: int64

# %%
knowspython=country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
knowspython
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
python_df=pd.concat([country_respondents,knowspython],axis='columns')

# %%
python_df
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Sao Tome and Principe                   1                   1
# Saint Vincent and the Grenadines        1                   0
# North Korea                             1                   0
# Brunei Darussalam                       1                   0
# Dominica                                1                   1
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'Numrespondents','LanguageWorkedWith':'knows_python'},inplace=True)

# %%
python_df
# Out:
#                                   Numrespondents  knows_python
# United States                              20949         10083
# India                                       9061          3105
# Germany                                     5866          2451
# United Kingdom                              5737          2384
# Canada                                      3395          1558
# ...                                          ...           ...
# Sao Tome and Principe                          1             1
# Saint Vincent and the Grenadines               1             0
# North Korea                                    1             0
# Brunei Darussalam                              1             0
# Dominica                                       1             1
#
# [179 rows x 2 columns]

# %%
python_df['Percentageknowspython']= (python_df['knows_python']/python_df['Numrespondents'])*100
python_df
# Out:
#                                   Numrespondents  knows_python  \
# United States                              20949         10083
# India                                       9061          3105
# Germany                                     5866          2451
# United Kingdom                              5737          2384
# Canada                                      3395          1558
# ...                                          ...           ...
# Sao Tome and Principe                          1             1
# Saint Vincent and the Grenadines               1             0
# North Korea                                    1             0
# Brunei Darussalam                              1             0
# Dominica                                       1             1
#
#                                   Percentageknowspython
# United States                                 48.131176
# India                                         34.267741
# ...

# %%
python_df.sort_values(by='Percentageknowspython',ascending=True,inplace=True)
python_df.head(10)
# Out:
#                                   Numrespondents  knows_python  \
# Lao People's Democratic Republic               3             0
# Liberia                                        2             0
# Chad                                           1             0
# Tonga                                          1             0
# Papua New Guinea                               1             0
# Brunei Darussalam                              1             0
# Saint Kitts and Nevis                          1             0
# Djibouti                                       2             0
# Malawi                                         2             0
# Antigua and Barbuda                            9             0
#
#                                   Percentageknowspython
# Lao People's Democratic Republic                    0.0
# Liberia                                             0.0
# Chad                                                0.0
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 75010     2
# 82369    10
# 280      25
# 4073     15
# 4770      8
# 7254     18
# 11961     5
# 13975    40
# 16363     2
# 17015     5
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['2', '10', '25', '15', '8', '18', '5', '40', '22', '12', '34',
#        '20', '35', '29', '24', '39', '23', '16', '6', '26', '30', '27',
#        '4', 'More than 50 years', '11', '14', '7', '9', '3', '37', '1',
#        'Less than 1 year', '28', '36', '32', '43', '17', '13', '50', nan,
#        '19', '33', '42', '31', '21', '38', '44', '45', '48', '41', '47',
#        '46', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array(['2', '10', '25', '15', '8', '18', '5', '40', '22', '12', '34',
#        '20', '35', '29', '24', '39', '23', '16', '6', '26', '30', '27',
#        '4', 51, '11', '14', '7', '9', '3', '37', '1', 0, '28', '36', '32',
#        '43', '17', '13', '50', nan, '19', '33', '42', '31', '21', '38',
#        '44', '45', '48', '41', '47', '46', '49'], dtype=object)

# %%
df['YearsCode']=df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0

# %%
df.describe()
# Out:
#           YearsCode     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  87938.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean      11.662114  5.519014e+11  1.271107e+05     42.127197      5.084308
# std        9.152772  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        0.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%        5.000000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%        9.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%       15.000000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max       51.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000
